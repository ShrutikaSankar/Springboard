# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import numpy as np
import pandas as pd
# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  

properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.shape
properties.info()
properties.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            301 non-null    datetime64[ns]
#  1   City of London        302 non-null    object
#  2   Barking & Dagenham    302 non-null    object
#  3   Barnet                302 non-null    object
#  4   Bexley                302 non-null    object
#  5   Brent                 302 non-null    object
#  6   Bromley               302 non-null    object
#  7   Camden                302 non-null    object
#  8   Croydon               302 non-null    object
#  9   Ealing                302 non-null    object
#  10  Enfield               302 non-null    object
#  11  Greenwich             302 non-null    object
#  12  Hackney               302 non-null    object
#  13  Hammersmith & Fulham  302 non-null    object
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_t= properties.T #Tranpose data
properties_t= properties_t.reset_index() # reset index
print(properties_t.index)
print(properties_t.iloc[0])
properties_t.columns = properties_t.iloc[0] #grab the first row for the header and assign it as column name
x = properties_t.iloc[0] #just in case
properties_t = properties_t[1:] #take the data less the header row
properties_t.head(1) # display head
# Out:
# RangeIndex(start=0, stop=49, step=1)
# index             Unnamed: 0
# 0                        NaT
# 1        1995-01-01 00:00:00
# 2        1995-02-01 00:00:00
# 3        1995-03-01 00:00:00
#                 ...
# 297      2019-09-01 00:00:00
# 298      2019-10-01 00:00:00
# 299      2019-11-01 00:00:00
# 300      2019-12-01 00:00:00
# 301      2020-01-01 00:00:00
# Name: 0, Length: 303, dtype: object
# 0      Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1  City of London  E09000001          91,448.985          82,202.773
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1          79,120.703          77,101.208          84,409.149
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1          94,900.512         110,128.042         112,329.438  ...
#
# 0 2019-04-01 00:00:00 2019-05-01 00:00:00 2019-06-01 00:00:00  \
# 1         738,841.781         718,773.271         743,157.498
#
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_t = properties_t.rename(columns = {'Unnamed: 0':'Boroughs', pd.NaT: 'ID'}) #this was straigh pasted from teir 1
propties_t_copy= properties_t.copy(deep=True) # just in case
properties_t.head(1)
# Out:
# 0        Boroughs         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1  City of London  E09000001          91,448.985          82,202.773
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1          79,120.703          77,101.208          84,409.149
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1          94,900.512         110,128.042         112,329.438  ...
#
# 0 2019-04-01 00:00:00 2019-05-01 00:00:00 2019-06-01 00:00:00  \
# 1         738,841.781         718,773.271         743,157.498
#
# 0 2019-07-01 00:00:00 2019-08-01 00:00:00 2019-09-01 00:00:00  \
# 1         719,870.902         777,613.308         792,033.942
#
# 0 2019-10-01 00:00:00 2019-11-01 00:00:00 2019-12-01 00:00:00  \
# 1         827,092.766         777,610.379         734,871.806
#
# 0 2020-01-01 00:00:00
# 1         775,308.889
#
# [1 rows x 303 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
y= pd.melt(properties_t,  id_vars=['Boroughs', 'ID'], value_name='avg_prices' , var_name= 'Date_H')
y.info()
y.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Boroughs    14448 non-null  object
#  1   ID          13545 non-null  object
#  2   Date_H      14448 non-null  datetime64[ns]
#  3   avg_prices  13545 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 451.6+ KB
#              Boroughs         ID     Date_H avg_prices
# 0      City of London  E09000001 1995-01-01 91,448.985
# 1  Barking & Dagenham  E09000002 1995-01-01 50,460.227
# 2              Barnet  E09000003 1995-01-01 93,284.518
# 3              Bexley  E09000004 1995-01-01 64,958.090
# 4               Brent  E09000005 1995-01-01 71,306.567

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
y['avg_prices'] = y.avg_prices.astype(float)
y['Date_H'].apply(lambda x: x.strftime('%d%m%Y'))
y.info(verbose=True)
y.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Boroughs    14448 non-null  object
#  1   ID          13545 non-null  object
#  2   Date_H      14448 non-null  datetime64[ns]
#  3   avg_prices  13545 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 451.6+ KB
#              Boroughs         ID     Date_H  avg_prices
# 0      City of London  E09000001 1995-01-01  91,448.985
# 1  Barking & Dagenham  E09000002 1995-01-01  50,460.227
# 2              Barnet  E09000003 1995-01-01  93,284.518
# 3              Bexley  E09000004 1995-01-01  64,958.090
# 4               Brent  E09000005 1995-01-01  71,306.567

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
y.info(verbose=True)
y = y[y['Boroughs'].notna()] #that did nothing
print(y[y.ID.isnull()]) # that has something
y = y[y['ID'].notna()] 
y.info(verbose=True) #number elements the same
print(y[y.avg_prices.isnull()]) # all values have prices
print(y.Boroughs.unique()) # England is not a boroughgh
y[y['Boroughs'] == 'England'].head() #later check... these must be averages
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Boroughs    14448 non-null  object
#  1   ID          13545 non-null  object
#  2   Date_H      14448 non-null  datetime64[ns]
#  3   avg_prices  13545 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 451.6+ KB
#           Boroughs   ID     Date_H  avg_prices
# 33     Unnamed: 34  NaN 1995-01-01         nan
# 36     Unnamed: 37  NaN 1995-01-01         nan
# 46     Unnamed: 47  NaN 1995-01-01         nan
# 81     Unnamed: 34  NaN 1995-02-01         nan
# 84     Unnamed: 37  NaN 1995-02-01         nan
# ...            ...  ...        ...         ...
# 14388  Unnamed: 37  NaN 2019-12-01         nan
# 14398  Unnamed: 47  NaN 2019-12-01         nan
# 14433  Unnamed: 34  NaN 2020-01-01         nan
# 14436  Unnamed: 37  NaN 2020-01-01         nan
# ...

# %%
z= y.Boroughs.unique()
non_Boroughs = z[-12:] 
Lon_Broughs = z[:-12]
properties_cleaned = y[y.Boroughs.isin(Lon_Broughs)] #cleaned properties contains only London Borughs
pc = properties_cleaned #alias
properties_ag = y[y.Boroughs.isin(non_Boroughs)] #properties_ag only contains larger properties ; just in casecamden_prices = df[df['London_Borough'] == 'Camden']
pc.head()
# Out:
#              Boroughs         ID     Date_H  avg_prices
# 0      City of London  E09000001 1995-01-01  91,448.985
# 1  Barking & Dagenham  E09000002 1995-01-01  50,460.227
# 2              Barnet  E09000003 1995-01-01  93,284.518
# 3              Bexley  E09000004 1995-01-01  64,958.090
# 4               Brent  E09000005 1995-01-01  71,306.567

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
brent_prices = pc[pc['Boroughs'] == 'Brent']
brent_prices.columns
plt.plot( 'Date_H', 'avg_prices', data=brent_prices, color='green')
plt.title('Brent Prices')
plt.xlabel("Date")
plt.ylabel("Average Price")
plt.show()
pc_avg_bor = pc.groupby('Date_H')['avg_prices'].mean()
plt.plot(pc_avg_bor, label = 'avg change')
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
pc['Year'] = pc['Date_H'].apply(lambda t: t.year) #easiest
pc.head()
pc.groupby('Boroughs')['Year'].min()-pc.groupby('Boroughs')['Year'].max() #They all have the same max and min year
pc_piv = pc.pivot_table(index= 'Boroughs', columns= 'Year', values= 'avg_prices', aggfunc= 'mean')#Create Pivot
#pc_piv['London_Boroughs']= pc_piv.index
pc_piv['Price_Diff_1996_2020'] = pc_piv[2020]/pc_piv[1996] #Find Difference
sort_by_price_change1996to2020 = pc_piv.sort_values('Price_Diff_1996_2020',ascending=False) #Sort
sort_by_price_change1996to2020 = sort_by_price_change1996to2020.reset_index()
pd.options.display.float_format = '{:,.3f}'.format

sort_by_price_change1996to2020[['Boroughs','Price_Diff_1996_2020']].head() #top5
# Out:
# C:\Users\Tiki\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Year        Boroughs  Price_Diff_1996_2020
# 0            Hackney                 8.259
# 1     City of London                 7.338
# 2        Westminster                 7.321
# 3     Waltham Forest                 7.274
# 4            Lambeth                 7.270

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
pc_piv['PriceRatio_1998_2018'] = pc_piv[2018]/pc_piv[1998] #Find Difference
sort_by_priceratio = pc_piv.sort_values('PriceRatio_1998_2018',ascending=False) #Sort
sort_by_priceratio['PriceRatio_1998_2018'].head() #top5
# Out:
# Boroughs
# Hackney          6.198
# Waltham Forest   5.835
# Southwark        5.516
# Lewisham         5.449
# Westminster      5.354
# Name: PriceRatio_1998_2018, dtype: float64

# %%
#That does not give a full look
pc_piv['PriceRatio_1996_2016'] = pc_piv[2016]/pc_piv[1996] #Find Difference
pc_piv['PriceRatio_1997_2017'] = pc_piv[2017]/pc_piv[1997] #Find Difference
pc_piv['PriceRatio_1998_2018'] = pc_piv[2018]/pc_piv[1998] #Find Difference
pc_piv['PriceRatio_1999_2019'] = pc_piv[2019]/pc_piv[1999] #Find Difference
pc_piv['PriceRatio_2000_2020'] = pc_piv[2020]/pc_piv[2000] #Find Difference


#above could probably have been a function buy this was easier to write
x = pc_piv.iloc[: , -6:]
x = x.reset_index()
p_list= x.columns[1:] 
c = []
d = []
for p in p_list:
    x = x.sort_values(p ,ascending=False)
    y = x.Boroughs[:3]
    for b in y:
        c.append(b)
top_4_boroughs = list(set(c))

print(top_4_boroughs)
for p in p_list:
    x = x.sort_values(p ,ascending=False)
    y = x.Boroughs[:2]
    for b in y:
        d.append(b)
top_3_boroughs = list(set(d))
print('The Top 3 Boroughs for increased prices are: '+str(top_3_boroughs))

pd.options.display.float_format = '{:,.3f}'.format
x = x.sort_values('Price_Diff_1996_2020',ascending=False) #Sort

x.head(10)
# Out:
# ['Westminster', 'Hackney', 'Newham', 'City of London', 'Waltham Forest', 'Southwark']
# The Top 3 Boroughs for increased prices are: ['Waltham Forest', 'Hackney', 'City of London']
# Year        Boroughs  Price_Diff_1996_2020  PriceRatio_1998_2018  \
# 11           Hackney                 8.259                 6.198
# 6     City of London                 7.338                 5.302
# 32       Westminster                 7.321                 5.354
# 30    Waltham Forest                 7.274                 5.835
# 21           Lambeth                 7.270                 4.958
# 27         Southwark                 7.168                 5.516
# 18         Islington                 6.937                 4.844
# 22          Lewisham                 6.888                 5.449
# 13          Haringey                 6.849                 5.135
# 24            Newham                 6.616                 5.305
#
# ...

# %%
#That does not give a full look

pc_piv2 = pc_piv.iloc[: ,:-6].copy(deep=True)
pc_piv2['Pricediff_1996_2016'] = pc_piv[2016]-pc_piv[1996] #Find Difference
pc_piv2['Pricediff_1998_2018'] = pc_piv[2018]-pc_piv[1998] #Find Difference
pc_piv2['Pricediiff_2000_2020'] = pc_piv[2020]-pc_piv[2000] #Find Difference
pc_piv2.head()
#above could probably have been a function buy this was easier to write
diff_pounds = pc_piv.iloc[: , -3:]
diff_pounds = diff_pounds.reset_index()
p_listd = diff_pounds.columns[1:] 
c = []
d = []
for p in p_listd:
    diff_pounds = diff_pounds.sort_values(p ,ascending=False)
    diff_pounds_y = diff_pounds.Boroughs[:3]
    for b in diff_pounds_y:
        c.append(b)
top_4_boroughs_price_diff = list(set(c))

# %%
for b in top_4_boroughs:
    z_prices = pc[pc['Boroughs'] == b]
    plt.plot( 'Date_H', 'avg_prices', data=z_prices, label= b )

plt.title('Prices')
plt.xlabel("Date")
plt.ylabel("Average Price")
plt.legend()
plt.show()
p_list_short= p_list[:2]
for p in p_list_short:
    x = x.sort_values(p ,ascending=False)
    x.plot(x= 'Boroughs' , y= p , kind= 'bar')

# %%
#Most expensive cities
q = pc_piv.iloc[: , :-6 ] # x's inverse just shows prices
q = q.reset_index()
qp_list= q.columns[1:] 
f = []
g = []
for qp in qp_list:
    q = q.sort_values(qp ,ascending=False)
    br = q.Boroughs[:3]
    for b in br:
        f.append(b)
top_4_expensive_borughs = list(set(f))

print(top_4_boroughs)

for qp in qp_list:
    q = q.sort_values(qp ,ascending=False)
    br = q.Boroughs[:1]
    for b in br:
        g.append(b)
top_2_expensive_borughs = list(set(f))

print('The Top 2  expensive Boroughs for increased prices are: '+str(top_4_expensive_borughs))
pd.options.display.float_format = '{:,.3f}'.format
q = q.sort_values(2020 ,ascending=False)

s= q[q['Boroughs'].isin(top_2_expensive_borughs)].T

s.columns = s.iloc[0] #grab the first row for the header and assign it as column name
x = s.iloc[0] #just in case
s = s[1:] #take the data less the header row
s.tail(10)
# Out:
# ['Westminster', 'Hackney', 'Newham', 'City of London', 'Waltham Forest', 'Southwark']
# The Top 2  expensive Boroughs for increased prices are: ['Westminster', 'Camden', 'Hammersmith & Fulham', 'City of London', 'Kensington & Chelsea']
# Boroughs Kensington & Chelsea   Westminster      Camden City of London  \
# Year
# 2011              908,565.091   632,513.603 554,392.963    463,930.776
# 2012            1,009,044.951   696,926.041 586,165.935    525,327.551
# 2013            1,126,572.700   789,972.477 667,447.559    570,008.714
# 2014            1,288,405.669   922,702.236 756,486.473    709,385.487
# 2015            1,302,102.725   964,643.072 787,440.933    760,253.019
# 2016            1,276,235.104   995,543.362 807,118.962    818,315.551
# 2017            1,344,539.732 1,064,771.597 839,347.476    849,790.096
# 2018            1,363,880.121 1,020,025.253 842,410.409    784,808.909
# 2019            1,247,124.537   958,303.997 838,532.945    786,983.144
# ...

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ### Preliminary report
#
# #### The largest % increase in annual average housing prices was seen in Hackney, Waltham Forest  and the City of London
#     *Hackney consistently saw the largest increase in prices over a twenty year span from 1996 to 2020, 1998 to 2020 and 1999 to 2019.
#     *Waltham Forest and City of London usually saw the second most increase over the same time period.
#
#
#
# #### The most expensive borough
#     *Chelsea was consistently the most expensive borough from 1996 to 2020.
#     *The next most expensive borough depended on the year but was one of the below:
#         * Westminster
#         * Camden
#         * City of London
#         * Hammersmith & Fulham
#
# #### Some Caveats
# *These results are only compared to other English Boroughs and does not look at larger areas*
#     * An more indepth understanding could be found if we wanted to compare northern vs southern england
# *This finding does not take into considerations any housing price fluctuations within the year*
#     * The absolute min - max difference would be a different study
#
# #### Challenges
#     *Doing python in jupter was difficult at first. It is not the enviorment I was used to.
#     *Most things I refreshed by looking at previous lessons.
#     * I ended up going back to teir 1 to copy a couple questions because I could not remember how to do that. Specifically
#         * Renaming a single column
#         * Anything with regard to formatting
#         * Most of the charts
#
#
# #### Further Investigations
#     *Depends on why we were asked this question.
#     * What was the average price change for each year; how did this compare to the highest paying ones?
#     * Which Boroughs changed the least?
#     *From personal curiosity I would love to see if other living expenses also increased like housing prices did for these districts
